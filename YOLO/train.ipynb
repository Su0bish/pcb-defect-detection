# %%
from ultralytics import YOLO
import cv2
from PIL import Image

# %%
# training -- DO NOT RUN
# Load the model.
model = YOLO('yolov8n.pt')
 
# Training.
results = model.train(
   data='fault.yaml',
   imgsz=640,
   epochs=10,
   batch=8,
   name='yolov8n_custom')
# Out:
# Ultralytics YOLOv8.1.11 🚀 Python-3.11.2 torch-2.0.0+cpu CPU (AMD Ryzen 5 5500U with Radeon Graphics)
# ...

# %%
# Load the trained weights
model = YOLO('runs/detect/yolov8n_custom/weights/best.pt')

# to run prediction on all images in a folder
im_dir = 'datasets/test/images'
results = model.predict(source=im_dir, save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# image 1/1067 c:\Users\subishram.s\Dropbox\PC\Desktop\project final\Tiny-Defect-Detection-for-PCB\YOLO\datasets\test\images\l_light_01_missing_hole_03_2_600.jpg: 640x640 1 missing_hole, 280.7ms
# image 2/1067 c:\Users\subishram.s\Dropbox\PC\Desktop\project final\Tiny-Defect-Detection-for-PCB\YOLO\datasets\test\images\l_light_01_missing_hole_10_3_600.jpg: 640x640 1 missing_hole, 224.0ms
# ...

# %%
# !yolo detect val model=runs/detect/yolov8n_custom/weights/best.pt data=fault.yaml split=test
# Out:
# Ultralytics YOLOv8.1.11 🚀 Python-3.11.2 torch-2.0.0+cpu CPU (AMD Ryzen 5 5500U with Radeon Graphics)
# Model summary (fused): 168 layers, 3006818 parameters, 0 gradients, 8.1 GFLOPs
# val: New cache created: C:\Users\subishram.s\Dropbox\PC\Desktop\project final\Tiny-Defect-Detection-for-PCB\YOLO\datasets\test\labels.cache
#                    all       1067       1600      0.969      0.944      0.972      0.519
#           missing_hole       1067        335      0.977      0.985      0.988      0.581
#             mouse_bite       1067        281      0.982      0.949      0.985      0.516
#           open_circuit       1067        254      0.971      0.965      0.985      0.511
#                  short       1067        254      0.963      0.929       0.95      0.521
#                   spur       1067        248      0.987       0.89      0.963      0.484
#        spurious_copper       1067        228      0.934      0.947      0.961      0.501
# ...

# %%
model = YOLO('runs/detect/yolov8n_custom/weights/best.pt')
# Run inference on single image
results_1 = model(r'.\datasets\test\images\l_light_01_missing_hole_14_4_600.jpg')  # results list

# Show the results
for r in results_1:
    im_array = r.plot()  # plot a BGR numpy array of predictions
    im = Image.fromarray(im_array[..., ::-1])  # RGB PIL image
    im.show()  # show image
# Out:
# image 1/1 c:\Users\subishram.s\Dropbox\PC\Desktop\project final\Tiny-Defect-Detection-for-PCB\YOLO\datasets\test\images\l_light_01_missing_hole_14_4_600.jpg: 640x640 1 missing_hole, 214.1ms
# Speed: 12.5ms preprocess, 214.1ms inference, 8.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
# !yolo task=detect mode=predict model=runs/detect/yolov8n_custom/weights/best.pt source=realtime.mp4 show=True imgsz=640 name=yolov8n_v8_50e_infer640 hide_labels=False
